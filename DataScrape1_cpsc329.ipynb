# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_data_breaches'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
soup.find('table')

# %%
soup.find('table' , class_='wikitable sortable')

# %%
table= soup.find_all('table')[1]

# %%
titles = table.find_all('th')

print(titles)
# Out:
# [<th>Entity</th>, <th>Year
# </th>, <th data-sort-type="number">Records</th>, <th>Organization type</th>, <th>Method</th>, <th>Sources
# </th>]

# %%
table_titles =  [title.text.strip() for title in titles]
print(table_titles)
# Out:
# ['Entity', 'Year', 'Records', 'Organization type', 'Method', 'Sources']

# %%
df= pd.DataFrame(columns = table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Entity, Year, Records, Organization type, Method, Sources]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
column_data
# Out:
# [<tr>
#  <th>Entity</th>
#  <th>Year
#  </th>
#  <th data-sort-type="number">Records</th>
#  <th>Organization type</th>
#  <th>Method</th>
#  <th>Sources
#  </th></tr>,
#  <tr>
#  <td>50 companies and government institutions
#  </td>
#  <td>2022
#  </td>
#  <td>6,400,000
#  </td>
#  <td>various
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-112"><a href="#cite_note-112">[112]</a></sup><sup class="reference" id="cite_ref-113"><a href="#cite_note-113">[113]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>21st Century Oncology
#  </td>
#  <td>2015
#  </td>
#  <td>2,200,000 customer's data, including names, Social Security numbers, physicians, diagnoses, insurance information
#  </td>
#  <td>healthcare
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-114"><a href="#cite_note-114">[114]</a></sup><sup class="reference" id="cite_ref-:2_115-0"><a href="#cite_note-:2-115">[115]</a></sup><sup class="reference" id="cite_ref-116"><a href="#cite_note-116">[116]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/23andMe_data_leak" title="23andMe data leak">23andMe data leak</a>
#  </td>
#  <td>2023
#  </td>
#  <td>6,900,000
#  </td>
#  <td>consumer genetics
#  </td>
#  <td>credential stuffing
#  </td>
#  <td><sup class="reference" id="cite_ref-117"><a href="#cite_note-117">[117]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/500px" title="500px">500px</a></td>
#  <td>2020
#  </td>
#  <td>14,870,304</td>
#  <td>social networking</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-theregister.co.uk_118-0"><a href="#cite_note-theregister.co.uk-118">[118]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Accendo Insurance Co.</td>
#  <td>2020
#  </td>
#  <td>175,350</td>
#  <td>healthcare</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-119"><a href="#cite_note-119">[119]</a></sup><sup class="reference" id="cite_ref-:3_120-0"><a href="#cite_note-:3-120">[120]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Jared_Ilovar" title="Jared Ilovar">Accenture</a></td>
#  <td>2007
#  </td>
#  <td></td>
#  <td></td>
#  <td>
#  </td>
#  <td><sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (May 2024)">citation needed</span></a></i>]</sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Adobe_Systems_Incorporated" title="Adobe Systems Incorporated">Adobe Systems Incorporated</a></td>
#  <td>2013
#  </td>
#  <td>152,000,000</td>
#  <td>tech</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-:6_121-0"><a href="#cite_note-:6-121">[121]</a></sup><sup class="reference" id="cite_ref-122"><a href="#cite_note-122">[122]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Adobe_Inc." title="Adobe Inc.">Adobe Inc.</a>
#  </td>
#  <td>2019
#  </td>
#  <td>7,500,000
#  </td>
#  <td>tech
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-:4_123-0"><a href="#cite_note-:4-123">[123]</a></sup><sup class="reference" id="cite_ref-:5_124-0"><a href="#cite_note-:5-124">[124]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Advocate Medical Group</td>
#  <td>2017
#  </td>
#  <td>4,000,000</td>
#  <td>healthcare</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-125"><a href="#cite_note-125">[125]</a></sup><sup class="reference" id="cite_ref-126"><a href="#cite_note-126">[126]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>AerServ (subsidiary of <a href="/wiki/InMobi" title="InMobi">InMobi</a>)
#  </td>
#  <td>2018
#  </td>
#  <td>75,000
#  </td>
#  <td>advertising
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-127"><a href="#cite_note-127">[127]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Affinity Health Plan, Inc.</td>
#  <td>2013
#  </td>
#  <td>344,579</td>
#  <td>healthcare</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-128"><a href="#cite_note-128">[128]</a></sup><sup class="reference" id="cite_ref-129"><a href="#cite_note-129">[129]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Bharti_Airtel" title="Bharti Airtel">Airtel</a>
#  </td>
#  <td>2019
#  </td>
#  <td>320,000,000
#  </td>
#  <td>telecommunications
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-130"><a href="#cite_note-130">[130]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Air_Canada" title="Air Canada">Air Canada</a>
#  </td>
#  <td>2018
#  </td>
#  <td>20,000
#  </td>
#  <td>transport
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-131"><a href="#cite_note-131">[131]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Amazon_(company)" title="Amazon (company)">Amazon Japan G.K.</a>
#  </td>
#  <td>2019
#  </td>
#  <td>unknown
#  </td>
#  <td>web
#  </td>
#  <td>accidentally published
#  </td>
#  <td><sup class="reference" id="cite_ref-132"><a href="#cite_note-132">[132]</a></sup><sup class="reference" id="cite_ref-133"><a href="#cite_note-133">[133]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/TD_Ameritrade" title="TD Ameritrade">TD Ameritrade</a></td>
#  <td>2005
#  </td>
#  <td>200,000</td>
#  <td>financial</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-134"><a href="#cite_note-134">[134]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Ameriprise_Financial" title="Ameriprise Financial">Ameriprise Financial</a></td>
#  <td>2005</td>
#  <td>260,000 customer records
#  </td>
#  <td>financial</td>
#  <td>stolen <a href="/wiki/Laptop" title="Laptop">laptop</a>
#  </td>
#  <td><sup class="reference" id="cite_ref-pri_135-0"><a href="#cite_note-pri-135">[135]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Ancestry.com" title="Ancestry.com">Ancestry.com</a>
#  </td>
#  <td>2021
#  </td>
#  <td>300,000
#  </td>
#  <td>web
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-136"><a href="#cite_note-136">[136]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Animal_Jam" title="Animal Jam">Animal Jam</a>
#  </td>
#  <td>2020
#  </td>
#  <td>46,000,000
#  </td>
#  <td>gaming
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-137"><a href="#cite_note-137">[137]</a></sup><sup class="reference" id="cite_ref-anj_1_138-0"><a href="#cite_note-anj_1-138">[138]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Ankle &amp; Foot Center of Tampa Bay, Inc.</td>
#  <td>2021
#  </td>
#  <td>156,000</td>
#  <td>healthcare</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-139"><a href="#cite_note-139">[139]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Anthem_Inc." title="Anthem Inc.">Anthem Inc.</a></td>
#  <td>2015
#  </td>
#  <td>80,000,000</td>
#  <td>healthcare</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-140"><a href="#cite_note-140">[140]</a></sup><sup class="reference" id="cite_ref-141"><a href="#cite_note-141">[141]</a></sup><sup class="reference" id="cite_ref-142"><a href="#cite_note-142">[142]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/AOL" title="AOL">AOL</a></td>
#  <td>2004
#  </td>
#  <td>92,000,000</td>
#  <td>web</td>
#  <td>inside job, hacked</td>
#  <td><sup class="reference" id="cite_ref-143"><a href="#cite_note-143">[143]</a></sup><sup class="reference" id="cite_ref-144"><a href="#cite_note-144">[144]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/AOL_search_log_release" title="AOL search log release">AOL</a></td>
#  <td>2006
#  </td>
#  <td>20,000,000</td>
#  <td>web</td>
#  <td>accidentally published, (sometimes referred to as a "Data <i><a href="/wiki/Exxon_Valdez_oil_spill" title="Exxon Valdez oil spill">Valdez</a></i>",<sup class="reference" id="cite_ref-145"><a href="#cite_note-145">[145]</a></sup><sup class="reference" id="cite_ref-146"><a href="#cite_note-146">[146]</a></sup><sup class="reference" id="cite_ref-147"><a href="#cite_note-147">[147]</a></sup> due to its size)</td>
#  <td><sup class="reference" id="cite_ref-148"><a href="#cite_note-148">[148]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/AOL" title="AOL">AOL</a></td>
#  <td>2014
#  </td>
#  <td>2,400,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-149"><a href="#cite_note-149">[149]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Apple_Inc." title="Apple Inc.">Apple</a> <a href="/wiki/ICloud" title="ICloud">iCloud</a></td>
#  <td>2014
#  </td>
#  <td data-sort-type="number"><a class="mw-redirect" href="/wiki/August_2014_celebrity_photo_leaks" title="August 2014 celebrity photo leaks">photographs of celebrities</a></td>
#  <td>tech, cloud storage</td>
#  <td></td>
#  <td><sup class="reference" id="cite_ref-150"><a href="#cite_note-150">[150]</a></sup><sup class="reference" id="cite_ref-151"><a href="#cite_note-151">[151]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Apple,_Inc." title="Apple, Inc.">Apple, Inc.</a>/BlueToad</td>
#  <td>2021
#  </td>
#  <td>12,367,232</td>
#  <td>tech, retail</td>
#  <td>accidentally published</td>
#  <td><sup class="reference" id="cite_ref-152"><a href="#cite_note-152">[152]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Apple_Inc." title="Apple Inc.">Apple</a></td>
#  <td>2013
#  </td>
#  <td>275,000</td>
#  <td>tech</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-153"><a href="#cite_note-153">[153]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Washington_Apple_Health" title="Washington Apple Health">Apple Health Medicaid</a></td>
#  <td>2021
#  </td>
#  <td>91,000</td>
#  <td>healthcare</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-154"><a href="#cite_note-154">[154]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Ashley_Madison_data_breach" title="Ashley Madison data breach">Ashley Madison</a></td>
#  <td>2015
#  </td>
#  <td>32,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-155"><a href="#cite_note-155">[155]</a></sup><sup class="reference" id="cite_ref-156"><a href="#cite_note-156">[156]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/AT%26T" title="AT&amp;T">AT&amp;T</a></td>
#  <td>2008
#  </td>
#  <td>113,000</td>
#  <td>telecoms</td>
#  <td>lost / stolen computer</td>
#  <td><sup class="reference" id="cite_ref-idtheftresourcecenterƒte_20-19"><a href="#cite_note-idtheftresourcecenterƒte-20">[20]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/AT%26T" title="AT&amp;T">AT&amp;T</a></td>
#  <td>2010
#  </td>
#  <td>114,000</td>
#  <td>telecoms</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-157"><a href="#cite_note-157">[157]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/AT%26T" title="AT&amp;T">AT&amp;T</a>
#  </td>
#  <td>2021
#  </td>
#  <td>72,000,000
#  </td>
#  <td>telecoms
#  </td>
#  <td>unknown
#  </td>
#  <td><sup class="reference" id="cite_ref-158"><a href="#cite_note-158">[158]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Atraf" title="Atraf">Atraf</a>
#  </td>
#  <td>2021
#  </td>
#  <td>unknown
#  </td>
#  <td>dating
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-159"><a href="#cite_note-159">[159]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Auction.co.kr</td>
#  <td>2008
#  </td>
#  <td>18,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-160"><a href="#cite_note-160">[160]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Automatic_Data_Processing" title="Automatic Data Processing">Automatic Data Processing</a></td>
#  <td>2005
#  </td>
#  <td>125,000</td>
#  <td>financial</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-161"><a href="#cite_note-161">[161]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>AvMed, Inc.</td>
#  <td>2009
#  </td>
#  <td>1,220,000</td>
#  <td>healthcare</td>
#  <td>lost / stolen computer</td>
#  <td><sup class="reference" id="cite_ref-162"><a href="#cite_note-162">[162]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Bailey's Inc.</td>
#  <td>2015
#  </td>
#  <td>250,000</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-163"><a href="#cite_note-163">[163]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/The_Bank_of_New_York_Mellon" title="The Bank of New York Mellon">The Bank of New York Mellon</a></td>
#  <td>2008
#  </td>
#  <td>12,500,000</td>
#  <td>financial</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-164"><a href="#cite_note-164">[164]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Bank_of_America" title="Bank of America">Bank of America</a>
#  </td>
#  <td>2005
#  </td>
#  <td>1,200,000
#  </td>
#  <td>financial
#  </td>
#  <td>lost / stolen media
#  </td>
#  <td><sup class="reference" id="cite_ref-165"><a href="#cite_note-165">[165]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Barnes_%26_Noble" title="Barnes &amp; Noble">Barnes &amp; Noble</a></td>
#  <td>2012
#  </td>
#  <td>63 stores</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-166"><a href="#cite_note-166">[166]</a></sup><sup class="reference" id="cite_ref-167"><a href="#cite_note-167">[167]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Bell_Canada" title="Bell Canada">Bell Canada</a>
#  </td>
#  <td>2017
#  </td>
#  <td>1,900,000
#  </td>
#  <td>telecoms
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-168"><a href="#cite_note-168">[168]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Bell_Canada" title="Bell Canada">Bell Canada</a>
#  </td>
#  <td>2018
#  </td>
#  <td>100,000
#  </td>
#  <td>telecoms
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-169"><a href="#cite_note-169">[169]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Benesse" title="Benesse">Benesse</a>
#  </td>
#  <td>2014
#  </td>
#  <td>35,040,000
#  </td>
#  <td>educational services
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-170"><a href="#cite_note-170">[170]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Betfair" title="Betfair">Betfair</a></td>
#  <td>2010
#  </td>
#  <td>2,300,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-idtheftresourcecenterƒte_20-20"><a href="#cite_note-idtheftresourcecenterƒte-20">[20]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Bethesda_Game_Studios" title="Bethesda Game Studios">Bethesda Game Studios</a></td>
#  <td>2011
#  </td>
#  <td>200,000</td>
#  <td>gaming</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-171"><a href="#cite_note-171">[171]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Bethesda_Game_Studios" title="Bethesda Game Studios">Bethesda Game Studios</a></td>
#  <td>2018
#  </td>
#  <td>customer names, addresses, contact details, partial credit card numbers</td>
#  <td>gaming</td>
#  <td>accidentally published</td>
#  <td><sup class="reference" id="cite_ref-172"><a href="#cite_note-172">[172]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Betsson" title="Betsson">Betsson Group</a>
#  </td>
#  <td>2020
#  </td>
#  <td>unknown
#  </td>
#  <td>gambling
#  </td>
#  <td>unknown
#  </td>
#  <td><sup class="reference" id="cite_ref-Betsson_173-0"><a href="#cite_note-Betsson-173">[173]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Blank_Media_Games" title="Blank Media Games">Blank Media Games</a>
#  </td>
#  <td>2018
#  </td>
#  <td>7,633,234
#  </td>
#  <td>gaming
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-174"><a href="#cite_note-174">[174]</a></sup><sup class="reference" id="cite_ref-175"><a href="#cite_note-175">[175]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Blizzard_Entertainment" title="Blizzard Entertainment">Blizzard Entertainment</a></td>
#  <td>2012
#  </td>
#  <td>14,000,000</td>
#  <td>gaming</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-176"><a href="#cite_note-176">[176]</a></sup><sup class="reference" id="cite_ref-177"><a href="#cite_note-177">[177]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/BlueCross_BlueShield_of_Tennessee" title="BlueCross BlueShield of Tennessee">BlueCross BlueShield of Tennessee</a></td>
#  <td>2009
#  </td>
#  <td>1,023,209</td>
#  <td>healthcare</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-178"><a href="#cite_note-178">[178]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/BMO_Harris_Bank" title="BMO Harris Bank">BMO</a> and <a href="/wiki/Simplii_Financial" title="Simplii Financial">Simplii</a></td>
#  <td>2018
#  </td>
#  <td>90,000</td>
#  <td>banking</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-179"><a href="#cite_note-179">[179]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Boeing" title="Boeing">Boeing</a></td>
#  <td>2006
#  </td>
#  <td>382,000 employees (after similar losses of data on 3,600 employees in April and 161,000 employees in November, 2005)</td>
#  <td>aviation</td>
#  <td><sup class="reference" id="cite_ref-pri_135-1"><a href="#cite_note-pri-135">[135]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/2018_British_Airways_cyberattack" title="2018 British Airways cyberattack">British Airways</a>
#  </td>
#  <td>2018
#  </td>
#  <td>500,000
#  </td>
#  <td>transport
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-180"><a href="#cite_note-180">[180]</a></sup><sup class="reference" id="cite_ref-181"><a href="#cite_note-181">[181]</a></sup><sup class="reference" id="cite_ref-182"><a href="#cite_note-182">[182]</a></sup><sup class="reference" id="cite_ref-183"><a href="#cite_note-183">[183]</a></sup><sup class="reference" id="cite_ref-184"><a href="#cite_note-184">[184]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/British_Airways" title="British Airways">British Airways</a></td>
#  <td>2015
#  </td>
#  <td data-sort-value="10000">tens of thousands</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-185"><a href="#cite_note-185">[185]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Canva" title="Canva">Canva</a>
#  </td>
#  <td>2019
#  </td>
#  <td>140,000,000
#  </td>
#  <td>web
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-186"><a href="#cite_note-186">[186]</a></sup><sup class="reference" id="cite_ref-187"><a href="#cite_note-187">[187]</a></sup><sup class="reference" id="cite_ref-188"><a href="#cite_note-188">[188]</a></sup><sup class="reference" id="cite_ref-189"><a href="#cite_note-189">[189]</a></sup><sup class="reference" id="cite_ref-190"><a href="#cite_note-190">[190]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Capcom" title="Capcom">Capcom</a>
#  </td>
#  <td>2020
#  </td>
#  <td>350,000
#  </td>
#  <td>game
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-March_2021_191-0"><a href="#cite_note-March_2021-191">[191]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Capital_One" title="Capital One">Capital One</a>
#  </td>
#  <td>2019
#  </td>
#  <td>106,000,000
#  </td>
#  <td>financial
#  </td>
#  <td>unsecured <a class="mw-redirect" href="/wiki/S3_bucket" title="S3 bucket">S3 bucket</a>
#  </td>
#  <td><sup class="reference" id="cite_ref-192"><a href="#cite_note-192">[192]</a></sup><sup class="reference" id="cite_ref-193"><a href="#cite_note-193">[193]</a></sup><sup class="reference" id="cite_ref-194"><a href="#cite_note-194">[194]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/CardSystems_Solutions" title="CardSystems Solutions">CardSystems Solutions</a> Inc.
#  <p><small>(MasterCard, Visa, Discover Financial Services and American Express)</small>
#  </p>
#  </td>
#  <td>2005
#  </td>
#  <td>40,000,000</td>
#  <td>financial</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-195"><a href="#cite_note-195">[195]</a></sup><sup class="reference" id="cite_ref-196"><a href="#cite_note-196">[196]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Cathay_Pacific_Airways" title="Cathay Pacific Airways">Cathay Pacific Airways</a>
#  </td>
#  <td>2018
#  </td>
#  <td>9,400,000
#  </td>
#  <td>transport
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-auto_197-0"><a href="#cite_note-auto-197">[197]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>CareFirst BlueCross Blue Shield - Maryland</td>
#  <td>2015
#  </td>
#  <td>1,100,000</td>
#  <td>healthcare</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-198"><a href="#cite_note-198">[198]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Central Coast Credit Union</td>
#  <td>2016
#  </td>
#  <td>60,000</td>
#  <td>financial</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-199"><a href="#cite_note-199">[199]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Central_Hudson_Energy_Group" title="Central Hudson Energy Group">Central Hudson Gas &amp; Electric</a></td>
#  <td>2013
#  </td>
#  <td>110,000</td>
#  <td>energy</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-privacyrights.org_44-2"><a href="#cite_note-privacyrights.org-44">[44]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Fiserv" title="Fiserv">CheckFree Corporation</a></td>
#  <td>2009
#  </td>
#  <td>5,000,000</td>
#  <td>financial</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-200"><a href="#cite_note-200">[200]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/CGI_Group" title="CGI Group">CGI Group</a></td>
#  <td>2007
#  </td>
#  <td>283,000
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td><sup class="reference" id="cite_ref-pri_135-2"><a href="#cite_note-pri-135">[135]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>CheckPeople</td>
#  <td>2020
#  </td>
#  <td>56,000,000</td>
#  <td>background check</td>
#  <td>unknown</td>
#  <td><sup class="reference" id="cite_ref-201"><a href="#cite_note-201">[201]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Chess.com" title="Chess.com">Chess.com</a>
#  </td>
#  <td>2023
#  </td>
#  <td>800,000
#  </td>
#  <td>game
#  </td>
#  <td>web scraping
#  </td>
#  <td><sup class="reference" id="cite_ref-202"><a href="#cite_note-202">[202]</a></sup><sup class="reference" id="cite_ref-203"><a href="#cite_note-203">[203]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Chinese_Software_Developer_Network" title="Chinese Software Developer Network">China Software Developer Network</a></td>
#  <td>2011
#  </td>
#  <td>6,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-204"><a href="#cite_note-204">[204]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Chinese gaming websites (three: Duowan, 7K7K, 178.com)</td>
#  <td>2011
#  </td>
#  <td>10,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-205"><a href="#cite_note-205">[205]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/ChoicePoint" title="ChoicePoint">ChoicePoint</a></td>
#  <td>2005
#  </td>
#  <td>163,000 consumer records</td>
#  <td>data aggregator</td>
#  <td>intentionally selling data</td>
#  <td><sup class="reference" id="cite_ref-nbc_206-0"><a href="#cite_note-nbc-206">[206]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Citigroup" title="Citigroup">Citigroup</a></td>
#  <td>2005
#  </td>
#  <td>3,900,000</td>
#  <td>financial</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-207"><a href="#cite_note-207">[207]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Citigroup</td>
#  <td>2011
#  </td>
#  <td>360,083</td>
#  <td>financial</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-208"><a href="#cite_note-208">[208]</a></sup><sup class="reference" id="cite_ref-209"><a href="#cite_note-209">[209]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Citigroup" title="Citigroup">Citigroup</a></td>
#  <td>2013
#  </td>
#  <td>150,000</td>
#  <td>financial</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-210"><a href="#cite_note-210">[210]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Healthcare_in_London" title="Healthcare in London">City and Hackney Teaching Primary Care Trust</a></td>
#  <td>2007
#  </td>
#  <td>160,000</td>
#  <td>healthcare</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-211"><a href="#cite_note-211">[211]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Clearview_AI" title="Clearview AI">Clearview AI</a></td>
#  <td>2020
#  </td>
#  <td>unknown (client list)</td>
#  <td>information technology</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-212"><a href="#cite_note-212">[212]</a></sup><sup class="reference" id="cite_ref-213"><a href="#cite_note-213">[213]</a></sup><sup class="reference" id="cite_ref-214"><a href="#cite_note-214">[214]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Collection_No._1" title="Collection No. 1">Collection No. 1</a>
#  </td>
#  <td>2019
#  </td>
#  <td>773,000,000
#  </td>
#  <td>various
#  </td>
#  <td>compilation of multiple data breaches
#  </td>
#  <td><sup class="reference" id="cite_ref-215"><a href="#cite_note-215">[215]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Community_Health_Systems" title="Community Health Systems">Community Health Systems</a></td>
#  <td>2014
#  </td>
#  <td>4,500,000</td>
#  <td>healthcare</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-216"><a href="#cite_note-216">[216]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/BBVA_Compass" title="BBVA Compass">Compass Bank</a></td>
#  <td>2007
#  </td>
#  <td>1,000,000</td>
#  <td>financial</td>
#  <td>inside job</td>
#  <td><sup class="reference" id="cite_ref-idtheftresourcecenterƒte_20-21"><a href="#cite_note-idtheftresourcecenterƒte-20">[20]</a></sup><sup class="reference" id="cite_ref-217"><a href="#cite_note-217">[217]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Bank_of_America_Home_Loans" title="Bank of America Home Loans">Countrywide Financial Corp</a></td>
#  <td>2006
#  </td>
#  <td>2,600,000</td>
#  <td>financial</td>
#  <td>inside job</td>
#  <td><sup class="reference" id="cite_ref-idtheftresourcecenterƒte_20-22"><a href="#cite_note-idtheftresourcecenterƒte-20">[20]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Bank_of_America_Home_Loans" title="Bank of America Home Loans">Countrywide Financial Corp</a></td>
#  <td>2011
#  </td>
#  <td>2,500,000</td>
#  <td>financial</td>
#  <td>inside job</td>
#  <td><sup class="reference" id="cite_ref-218"><a href="#cite_note-218">[218]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Countrywide_Financial" title="Countrywide Financial">Countrywide Financial</a></td>
#  <td>2008
#  </td>
#  <td>Records</td>
#  <td>finance</td>
#  <td>insider theft</td>
#  <td><sup class="reference" id="cite_ref-219"><a href="#cite_note-219">[219]</a></sup><sup class="reference" id="cite_ref-220"><a href="#cite_note-220">[220]</a></sup><sup class="reference" id="cite_ref-221"><a href="#cite_note-221">[221]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Cox_Communications" title="Cox Communications">Cox Communications</a></td>
#  <td>2016
#  </td>
#  <td>40,000</td>
#  <td>telecoms</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-222"><a href="#cite_note-222">[222]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Crescent_Enterprises" title="Crescent Enterprises">Crescent Health Inc.</a>, <a href="/wiki/Walgreens" title="Walgreens">Walgreens</a></td>
#  <td>2013
#  </td>
#  <td>100,000</td>
#  <td>healthcare</td>
#  <td>lost / stolen computer</td>
#  <td><sup class="reference" id="cite_ref-privacyrights.org_44-3"><a href="#cite_note-privacyrights.org-44">[44]</a></sup><sup class="reference" id="cite_ref-223"><a href="#cite_note-223">[223]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Cutout.Pro
#  </td>
#  <td>2024
#  </td>
#  <td>19,972,829
#  </td>
#  <td>web
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-224"><a href="#cite_note-224">[224]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/CVS_Health" title="CVS Health">CVS</a></td>
#  <td>2015
#  </td>
#  <td data-sort-value="1000000">millions</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-nytimes.com_225-0"><a href="#cite_note-nytimes.com-225">[225]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>CyberServe</td>
#  <td>2021
#  </td>
#  <td>1,107,034</td>
#  <td>hosting provider</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-226"><a href="#cite_note-226">[226]</a></sup><sup class="reference" id="cite_ref-227"><a href="#cite_note-227">[227]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>D. A. Davidson &amp; Co.</td>
#  <td>2007
#  </td>
#  <td>192,000 clients' names, customer account and social security numbers, addresses and dates of birth
#  </td>
#  <td>broker/dealer
#  </td>
#  <td>hacked by Latvian hackers
#  </td>
#  <td><sup class="reference" id="cite_ref-D.A._Davidson_&amp;_Co._228-0"><a href="#cite_note-D.A._Davidson_&amp;_Co.-228">[228]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Dai_Nippon_Printing" title="Dai Nippon Printing">Dai Nippon Printing</a></td>
#  <td>2007
#  </td>
#  <td>8,637,405</td>
#  <td>retail</td>
#  <td>inside job</td>
#  <td><sup class="reference" id="cite_ref-229"><a href="#cite_note-229">[229]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Data Processors International<br/><small> (MasterCard, Visa, Discover Financial Services and American Express)</small></td>
#  <td>2008
#  </td>
#  <td>8,000,000</td>
#  <td>financial</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-230"><a href="#cite_note-230">[230]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/DC_Health_Link" title="DC Health Link">DC Health Link</a>
#  </td>
#  <td>2023
#  </td>
#  <td>56,000
#  </td>
#  <td>healthcare
#  </td>
#  <td>misconfigured website
#  </td>
#  <td><sup class="reference" id="cite_ref-231"><a href="#cite_note-231">[231]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Dedalus Biologie (a division of <a class="new" href="/w/index.php?title=Dedalus_(medical_software_company)&amp;action=edit&amp;redlink=1" title="Dedalus (medical software company) (page does not exist)">Dedalus Global</a>)
#  </td>
#  <td>2021
#  </td>
#  <td>500,000
#  </td>
#  <td>health
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-232"><a href="#cite_note-232">[232]</a></sup><sup class="reference" id="cite_ref-233"><a href="#cite_note-233">[233]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Deloitte" title="Deloitte">Deloitte</a>
#  </td>
#  <td>2017
#  </td>
#  <td>350 clients emails
#  </td>
#  <td>consulting, accounting
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-234"><a href="#cite_note-234">[234]</a></sup><sup class="reference" id="cite_ref-235"><a href="#cite_note-235">[235]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Desjardins_Group" title="Desjardins Group">Desjardins</a>
#  </td>
#  <td>2019
#  </td>
#  <td>9,700,000
#  </td>
#  <td>financial
#  </td>
#  <td>inside job
#  </td>
#  <td><sup class="reference" id="cite_ref-236"><a href="#cite_note-236">[236]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Domino%27s_Pizza" title="Domino's Pizza">Domino's Pizza</a> (France)</td>
#  <td>2014
#  </td>
#  <td>600,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-237"><a href="#cite_note-237">[237]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="new" href="/w/index.php?title=DonorView&amp;action=edit&amp;redlink=1" title="DonorView (page does not exist)">DonorView</a></td>
#  <td>2023
#  </td>
#  <td>948,029</td>
#  <td>charity</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-238"><a href="#cite_note-238">[238]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/DoorDash" title="DoorDash">DoorDash</a></td>
#  <td>2019
#  </td>
#  <td>4,900,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-239"><a href="#cite_note-239">[239]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Dropbox_(service)" title="Dropbox (service)">Dropbox</a></td>
#  <td>2012
#  </td>
#  <td>68,648,009</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-240"><a href="#cite_note-240">[240]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Drupal" title="Drupal">Drupal</a></td>
#  <td>2013
#  </td>
#  <td>1,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-241"><a href="#cite_note-241">[241]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/DSW,_Inc." title="DSW, Inc.">DSW Inc.</a>
#  </td>
#  <td>2005
#  </td>
#  <td>1,400,000
#  </td>
#  <td>retail
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-242"><a href="#cite_note-242">[242]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Dubsmash" title="Dubsmash">Dubsmash</a></td>
#  <td>2018
#  </td>
#  <td>162,000,000</td>
#  <td>messaging app</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-243"><a href="#cite_note-243">[243]</a></sup><sup class="reference" id="cite_ref-theregister.co.uk_118-1"><a href="#cite_note-theregister.co.uk-118">[118]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Dun_%26_Bradstreet" title="Dun &amp; Bradstreet">Dun &amp; Bradstreet</a></td>
#  <td>2013
#  </td>
#  <td>1,000,000</td>
#  <td>tech</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-byronacohido,usatoday_244-0"><a href="#cite_note-byronacohido,usatoday-244">[244]</a></sup><sup class="reference" id="cite_ref-jimfinkle_245-0"><a href="#cite_note-jimfinkle-245">[245]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Duolingo" title="Duolingo">Duolingo</a>
#  </td>
#  <td>2023
#  </td>
#  <td>2,676,696
#  </td>
#  <td>educational services
#  </td>
#  <td>web scraping
#  </td>
#  <td><sup class="reference" id="cite_ref-:6_121-1"><a href="#cite_note-:6-121">[121]</a></sup><sup class="reference" id="cite_ref-246"><a href="#cite_note-246">[246]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Earl Enterprises<br/><small>(<a href="/wiki/Buca_di_Beppo" title="Buca di Beppo">Buca di Beppo</a>, <a href="/wiki/Earl_of_Sandwich_(restaurant)" title="Earl of Sandwich (restaurant)">Earl of Sandwich</a>, <a href="/wiki/Planet_Hollywood" title="Planet Hollywood">Planet Hollywood</a>,<br/>Chicken Guy, Mixology, Tequila Taqueria)</small></td>
#  <td>2018-2019
#  </td>
#  <td>2,000,000</td>
#  <td>restaurant</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-247"><a href="#cite_note-247">[247]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/EasyJet_hack" title="EasyJet hack">EasyJet</a></td>
#  <td>2019-2020
#  </td>
#  <td>9,000,000 (approx) - basic booking, 2208 (credit card details)</td>
#  <td>transport</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-bbc-easyjet-admits-data-of-nine-million-hacked_248-0"><a href="#cite_note-bbc-easyjet-admits-data-of-nine-million-hacked-248">[248]</a></sup><sup class="reference" id="cite_ref-independent-easyjet-data-hack-news-cyber-attack-passengers-personal-information_249-0"><a href="#cite_note-independent-easyjet-data-hack-news-cyber-attack-passengers-personal-information-249">[249]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/EBay" title="EBay">eBay</a></td>
#  <td>2014
#  </td>
#  <td>145,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-250"><a href="#cite_note-250">[250]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Educational_Credit_Management_Corporation" title="Educational Credit Management Corporation">Educational Credit Management Corporation</a></td>
#  <td>2010
#  </td>
#  <td>3,300,000</td>
#  <td>financial</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-251"><a href="#cite_note-251">[251]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Eisenhower_Medical_Center" title="Eisenhower Medical Center">Eisenhower Medical Center</a></td>
#  <td>2011
#  </td>
#  <td>514,330</td>
#  <td>healthcare</td>
#  <td>lost / stolen computer</td>
#  <td><sup class="reference" id="cite_ref-hhs.gov_73-2"><a href="#cite_note-hhs.gov-73">[73]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/ElasticSearch" title="ElasticSearch">ElasticSearch</a></td>
#  <td>2019
#  </td>
#  <td>108,000,000</td>
#  <td>tech</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-252"><a href="#cite_note-252">[252]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Emergency Healthcare Physicians, Ltd.</td>
#  <td>2010
#  </td>
#  <td>180,111</td>
#  <td>healthcare</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-hhs.gov_73-3"><a href="#cite_note-hhs.gov-73">[73]</a></sup><sup class="reference" id="cite_ref-253"><a href="#cite_note-253">[253]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Emory_Healthcare" title="Emory Healthcare">Emory Healthcare</a></td>
#  <td>2012
#  </td>
#  <td>315,000</td>
#  <td>healthcare</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-hhs.gov_73-4"><a href="#cite_note-hhs.gov-73">[73]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Epic_Games" title="Epic Games">Epic Games</a> <a href="/wiki/Fortnite" title="Fortnite">Fortnite</a></td>
#  <td>2018
#  </td>
#  <td>user accounts</td>
#  <td>gaming</td>
#  <td>vulnerability</td>
#  <td><sup class="reference" id="cite_ref-254"><a href="#cite_note-254">[254]</a></sup><sup class="reference" id="cite_ref-255"><a href="#cite_note-255">[255]</a></sup><sup class="reference" id="cite_ref-256"><a href="#cite_note-256">[256]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/2021_Epik_data_breach" title="2021 Epik data breach">Epik</a></td>
#  <td>2021
#  </td>
#  <td></td>
#  <td></td>
#  <td></td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Ernst_%26_Young" title="Ernst &amp; Young">Ernst &amp; Young</a>
#  </td>
#  <td>2006
#  </td>
#  <td>234,000 customers of <a href="/wiki/Hotels.com" title="Hotels.com">Hotels.com</a> (after a similar loss of data on 38,000 employees of Ernst &amp; Young clients in February)
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td><sup class="reference" id="cite_ref-pri_135-3"><a href="#cite_note-pri-135">[135]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Equifax" title="Equifax">Equifax</a>
#  </td>
#  <td>2017
#  </td>
#  <td>163,119,000
#  </td>
#  <td>financial, credit reporting
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-257"><a href="#cite_note-257">[257]</a></sup><sup class="reference" id="cite_ref-258"><a href="#cite_note-258">[258]</a></sup><sup class="reference" id="cite_ref-Forbes_259-0"><a href="#cite_note-Forbes-259">[259]</a></sup><sup class="reference" id="cite_ref-BGR_260-0"><a href="#cite_note-BGR-260">[260]</a></sup><sup class="reference" id="cite_ref-261"><a href="#cite_note-261">[261]</a></sup><sup class="reference" id="cite_ref-262"><a href="#cite_note-262">[262]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/EssilorLuxottica#Data_breach" title="EssilorLuxottica">EssilorLuxottica</a>
#  </td>
#  <td>2021
#  </td>
#  <td>77,093,812
#  </td>
#  <td>healthcare, retail
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-263"><a href="#cite_note-263">[263]</a></sup><sup class="reference" id="cite_ref-Have_I_Been_Pwned:_Pwned_websites_264-0"><a href="#cite_note-Have_I_Been_Pwned:_Pwned_websites-264">[264]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Evernote" title="Evernote">Evernote</a></td>
#  <td>2013
#  </td>
#  <td>50,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-265"><a href="#cite_note-265">[265]</a></sup><sup class="reference" id="cite_ref-266"><a href="#cite_note-266">[266]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Evide_data_breach" title="Evide data breach">Evide data breach</a></td>
#  <td>2023
#  </td>
#  <td>1,000</td>
#  <td>computer services for charities</td>
#  <td>ransomware hacked</td>
#  <td><sup class="reference" id="cite_ref-ie-abuse-victims-warned-over-dodgy-emails_267-0"><a href="#cite_note-ie-abuse-victims-warned-over-dodgy-emails-267">[267]</a></sup><sup class="reference" id="cite_ref-ie-charities-for-abuse-victims-may-face-sanctions_268-0"><a href="#cite_note-ie-charities-for-abuse-victims-may-face-sanctions-268">[268]</a></sup><sup class="reference" id="cite_ref-bbc-cyber-attack-data-from-charities-stolen_269-0"><a href="#cite_note-bbc-cyber-attack-data-from-charities-stolen-269">[269]</a></sup><sup class="reference" id="cite_ref-tj-investigation-underway-into-cyber-attack_270-0"><a href="#cite_note-tj-investigation-underway-into-cyber-attack-270">[270]</a></sup><sup class="reference" id="cite_ref-it-sex-abuse-survivors-charity-one-in-four-victim-of-data-breach_271-0"><a href="#cite_note-it-sex-abuse-survivors-charity-one-in-four-victim-of-data-breach-271">[271]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Exactis" title="Exactis">Exactis</a></td>
#  <td>2018
#  </td>
#  <td>340,000,000</td>
#  <td>data broker</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-272"><a href="#cite_note-272">[272]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Excellus_BlueCross_BlueShield" title="Excellus BlueCross BlueShield">Excellus BlueCross BlueShield</a></td>
#  <td>2015
#  </td>
#  <td>10,000,000</td>
#  <td>healthcare</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-273"><a href="#cite_note-273">[273]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Experian" title="Experian">Experian</a> - <a href="/wiki/T-Mobile_US" title="T-Mobile US">T-Mobile US</a></td>
#  <td>2015
#  </td>
#  <td>15,000,000</td>
#  <td>telecoms</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-274"><a href="#cite_note-274">[274]</a></sup><sup class="reference" id="cite_ref-275"><a href="#cite_note-275">[275]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/EyeWire" title="EyeWire">EyeWire</a></td>
#  <td>2016
#  </td>
#  <td>unknown</td>
#  <td>tech</td>
#  <td>lost / stolen computer</td>
#  <td><sup class="reference" id="cite_ref-276"><a href="#cite_note-276">[276]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Facebook" title="Facebook">Facebook</a></td>
#  <td>2013
#  </td>
#  <td>6,000,000</td>
#  <td>social network</td>
#  <td>accidentally published</td>
#  <td><sup class="reference" id="cite_ref-277"><a href="#cite_note-277">[277]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Facebook" title="Facebook">Facebook</a>
#  </td>
#  <td>2018
#  </td>
#  <td>50,000,000
#  </td>
#  <td>social network
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-278"><a href="#cite_note-278">[278]</a></sup><sup class="reference" id="cite_ref-279"><a href="#cite_note-279">[279]</a></sup><sup class="reference" id="cite_ref-280"><a href="#cite_note-280">[280]</a></sup><sup class="reference" id="cite_ref-281"><a href="#cite_note-281">[281]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Facebook" title="Facebook">Facebook</a>
#  </td>
#  <td>2010s
#  </td>
#  <td>87,000,000
#  </td>
#  <td>social network
#  </td>
#  <td><a href="/wiki/Facebook%E2%80%93Cambridge_Analytica_data_scandal" title="Facebook–Cambridge Analytica data scandal">data misuse</a>
#  </td>
#  <td><sup class="reference" id="cite_ref-282"><a href="#cite_note-282">[282]</a></sup><sup class="reference" id="cite_ref-283"><a href="#cite_note-283">[283]</a></sup><sup class="reference" id="cite_ref-guardian_original_284-0"><a href="#cite_note-guardian_original-284">[284]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Facebook" title="Facebook">Facebook</a>
#  </td>
#  <td>2019
#  </td>
#  <td>540,000,000
#  </td>
#  <td>social network
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-285"><a href="#cite_note-285">[285]</a></sup><sup class="reference" id="cite_ref-286"><a href="#cite_note-286">[286]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Facebook" title="Facebook">Facebook</a>
#  </td>
#  <td>2019
#  </td>
#  <td>1,500,000
#  </td>
#  <td>social network
#  </td>
#  <td>accidentally uploaded
#  </td>
#  <td><sup class="reference" id="cite_ref-287"><a href="#cite_note-287">[287]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Facebook" title="Facebook">Facebook</a></td>
#  <td>2019
#  </td>
#  <td>267,000,000</td>
#  <td>social network</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-288"><a href="#cite_note-288">[288]</a></sup><sup class="reference" id="cite_ref-289"><a href="#cite_note-289">[289]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Facebook_Marketplace" title="Facebook Marketplace">Facebook Marketplace</a>
#  </td>
#  <td>2023
#  </td>
#  <td>200,000
#  </td>
#  <td>social network
#  </td>
#  <td>unknown
#  </td>
#  <td><sup class="reference" id="cite_ref-290"><a href="#cite_note-290">[290]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Fast_Retailing" title="Fast Retailing">Fast Retailing</a></td>
#  <td>2019
#  </td>
#  <td>461,091</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-ReferenceA_291-0"><a href="#cite_note-ReferenceA-291">[291]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Fidelity National Information Services</td>
#  <td>2007
#  </td>
#  <td>8,500,000</td>
#  <td>financial</td>
#  <td>inside job</td>
#  <td><sup class="reference" id="cite_ref-292"><a href="#cite_note-292">[292]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/First_American_Corporation" title="First American Corporation">First American Corporation</a>
#  </td>
#  <td>2019
#  </td>
#  <td>885,000,000
#  </td>
#  <td>financial service company
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-293"><a href="#cite_note-293">[293]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>FireEye
#  </td>
#  <td>2020
#  </td>
#  <td>Unknown
#  </td>
#  <td>Information Security
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-toi_294-0"><a href="#cite_note-toi-294">[294]</a></sup><sup class="reference" id="cite_ref-nyt-2020-12-08_295-0"><a href="#cite_note-nyt-2020-12-08-295">[295]</a></sup><sup class="reference" id="cite_ref-296"><a href="#cite_note-296">[296]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Friend_Finder_Networks" title="Friend Finder Networks">Friend Finder Networks</a></td>
#  <td>2016
#  </td>
#  <td>412,214,295</td>
#  <td>web</td>
#  <td>poor security / hacked</td>
#  <td><sup class="reference" id="cite_ref-verge-affhack16_297-0"><a href="#cite_note-verge-affhack16-297">[297]</a></sup><sup class="reference" id="cite_ref-zdnet-breach_298-0"><a href="#cite_note-zdnet-breach-298">[298]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Funimation" title="Funimation">Funimation</a></td>
#  <td>2016
#  </td>
#  <td>2,500,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-299"><a href="#cite_note-299">[299]</a></sup><sup class="reference" id="cite_ref-300"><a href="#cite_note-300">[300]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Formstack" title="Formstack">Formspring</a></td>
#  <td>2012
#  </td>
#  <td>420,000</td>
#  <td>web</td>
#  <td>accidentally published</td>
#  <td><sup class="reference" id="cite_ref-301"><a href="#cite_note-301">[301]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="new" href="/w/index.php?title=Gamigo_AG&amp;action=edit&amp;redlink=1" title="Gamigo AG (page does not exist)">Gamigo</a></td>
#  <td>2012
#  </td>
#  <td>8,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-302"><a href="#cite_note-302">[302]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Gap_Inc." title="Gap Inc.">Gap Inc.</a></td>
#  <td>2007
#  </td>
#  <td>800,000</td>
#  <td>retail</td>
#  <td>lost / stolen computer</td>
#  <td><sup class="reference" id="cite_ref-303"><a href="#cite_note-303">[303]</a></sup><sup class="reference" id="cite_ref-pri_135-4"><a href="#cite_note-pri-135">[135]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Gawker" title="Gawker">Gawker</a></td>
#  <td>2010
#  </td>
#  <td>1,500,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-304"><a href="#cite_note-304">[304]</a></sup><sup class="reference" id="cite_ref-305"><a href="#cite_note-305">[305]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/GE_Money" title="GE Money">GE Money</a></td>
#  <td>2008
#  </td>
#  <td>650,000 customer's data, including 150,000 social security numbers and in-store <a href="/wiki/Credit_card" title="Credit card">credit card</a> information from retail customers</td>
#  <td>financial</td>
#  <td>magnetic tape missing from an <a class="mw-redirect" href="/wiki/Iron_Mountain_Incorporated" title="Iron Mountain Incorporated">Iron Mountain Incorporated</a> storage facility</td>
#  <td><sup class="reference" id="cite_ref-306"><a href="#cite_note-306">[306]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Global_Payments" title="Global Payments">Global Payments</a></td>
#  <td>2012
#  </td>
#  <td>7,000,000</td>
#  <td>financial</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-307"><a href="#cite_note-307">[307]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Gmail" title="Gmail">Gmail</a></td>
#  <td>2014
#  </td>
#  <td>5,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-308"><a href="#cite_note-308">[308]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Google_Plus" title="Google Plus">Google Plus</a>
#  </td>
#  <td>2018
#  </td>
#  <td>500,000
#  </td>
#  <td>social network
#  </td>
#  <td>poor security
#  </td>
# ...
#  </td></tr>,
#  <tr>
#  <td>Tetrad</td>
#  <td>2020
#  </td>
#  <td>120,000,000</td>
#  <td>market analysis</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-487"><a href="#cite_note-487">[487]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Ticketfly" title="Ticketfly">Ticketfly</a> (subsidiary of <a href="/wiki/Eventbrite" title="Eventbrite">Eventbrite</a>)
#  </td>
#  <td>2018
#  </td>
#  <td>26,151,608
#  </td>
#  <td>ticket distribution
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-488"><a href="#cite_note-488">[488]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Tic Hosting Solutions (known as Torchbyte)</td>
#  <td>2023
#  </td>
#  <td>unknown</td>
#  <td>hosting provider</td>
#  <td>hacked / poor security</td>
#  <td><sup class="reference" id="cite_ref-489"><a href="#cite_note-489">[489]</a></sup><sup class="reference" id="cite_ref-DataBreaches.net_344-1"><a href="#cite_note-DataBreaches.net-344">[344]</a></sup><sup class="reference" id="cite_ref-490"><a href="#cite_note-490">[490]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Tianya_Club" title="Tianya Club">Tianya Club</a></td>
#  <td>2011
#  </td>
#  <td>28,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-491"><a href="#cite_note-491">[491]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/TikTok" title="TikTok">TikTok</a>
#  </td>
#  <td>2020
#  </td>
#  <td>42,000,000
#  </td>
#  <td>social media
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-Winder_343-1"><a href="#cite_note-Winder-343">[343]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>TK / <a href="/wiki/TJ_Maxx" title="TJ Maxx">TJ Maxx</a></td>
#  <td>2007
#  </td>
#  <td>94,000,000</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-492"><a href="#cite_note-492">[492]</a></sup><sup class="reference" id="cite_ref-493"><a href="#cite_note-493">[493]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/T-Mobile_International_AG" title="T-Mobile International AG">T-Mobile</a>, <a href="/wiki/Deutsche_Telekom" title="Deutsche Telekom">Deutsche Telekom</a></td>
#  <td>2006
#  </td>
#  <td>17,000,000</td>
#  <td>telecoms</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-494"><a href="#cite_note-494">[494]</a></sup><sup class="reference" id="cite_ref-495"><a href="#cite_note-495">[495]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/T-Mobile_International_AG" title="T-Mobile International AG">T-Mobile</a></td>
#  <td>2021
#  </td>
#  <td>45,000,000</td>
#  <td>telecom</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-496"><a href="#cite_note-496">[496]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/T-Mobile_International_AG" title="T-Mobile International AG">T-Mobile</a></td>
#  <td>2023
#  </td>
#  <td>37,000,000</td>
#  <td>telecom</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-497"><a href="#cite_note-497">[497]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Tokopedia" title="Tokopedia">Tokopedia</a></td>
#  <td>2020
#  </td>
#  <td>91,000,000</td>
#  <td>online shopping</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-498"><a href="#cite_note-498">[498]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Trello" title="Trello">Trello</a>
#  </td>
#  <td>2024
#  </td>
#  <td>15,111,945
#  </td>
#  <td>tech
#  </td>
#  <td>misconfigured API
#  </td>
#  <td><sup class="reference" id="cite_ref-499"><a href="#cite_note-499">[499]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Triple-S Salud, Inc.</td>
#  <td>2010
#  </td>
#  <td>398,000</td>
#  <td>healthcare</td>
#  <td>lost / stolen media</td>
#  <td><sup class="reference" id="cite_ref-hhs.gov_73-12"><a href="#cite_note-hhs.gov-73">[73]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Truecaller" title="Truecaller">Truecaller</a></td>
#  <td>2019
#  </td>
#  <td>299,055,000</td>
#  <td>Telephone directory</td>
#  <td>unknown</td>
#  <td><sup class="reference" id="cite_ref-500"><a href="#cite_note-500">[500]</a></sup><sup class="reference" id="cite_ref-501"><a href="#cite_note-501">[501]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Trump_Hotels" title="Trump Hotels">Trump Hotels</a></td>
#  <td>2014
#  </td>
#  <td>8 locations</td>
#  <td>hotel</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-502"><a href="#cite_note-502">[502]</a></sup><sup class="reference" id="cite_ref-503"><a href="#cite_note-503">[503]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Tumblr" title="Tumblr">Tumblr</a>
#  </td>
#  <td>2013
#  </td>
#  <td>65,469,298
#  </td>
#  <td>web
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-504"><a href="#cite_note-504">[504]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Twitch_(service)" title="Twitch (service)">Twitch</a></td>
#  <td>2015
#  </td>
#  <td>unknown</td>
#  <td>tech</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-505"><a href="#cite_note-505">[505]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Twitch_(service)" title="Twitch (service)">Twitch</a></td>
#  <td>2021
#  </td>
#  <td>unknown</td>
#  <td>tech</td>
#  <td>hacked/misconfiguration</td>
#  <td><sup class="reference" id="cite_ref-506"><a href="#cite_note-506">[506]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Twitter" title="Twitter">Twitter</a></td>
#  <td>2013
#  </td>
#  <td>250,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-507"><a href="#cite_note-507">[507]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Typeform_(service)" title="Typeform (service)">Typeform</a>
#  </td>
#  <td>2018
#  </td>
#  <td>unknown
#  </td>
#  <td>tech
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-auto_197-1"><a href="#cite_note-auto-197">[197]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Uber" title="Uber">Uber</a></td>
#  <td>2014
#  </td>
#  <td>50,000</td>
#  <td>tech</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-508"><a href="#cite_note-508">[508]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Uber" title="Uber">Uber</a>
#  </td>
#  <td>2017
#  </td>
#  <td>57,000,000
#  </td>
#  <td>transport
#  </td>
#  <td>hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-509"><a href="#cite_note-509">[509]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Ubisoft" title="Ubisoft">Ubisoft</a></td>
#  <td>2013
#  </td>
#  <td>unknown</td>
#  <td>gaming</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-510"><a href="#cite_note-510">[510]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Ubuntu_(operating_system)" title="Ubuntu (operating system)">Ubuntu</a></td>
#  <td>2013
#  </td>
#  <td>2,000,000</td>
#  <td>tech</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-511"><a href="#cite_note-511">[511]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/UCLA_Medical_Center,_Santa_Monica" title="UCLA Medical Center, Santa Monica">UCLA Medical Center, Santa Monica</a></td>
#  <td>2015
#  </td>
#  <td>4,500,000</td>
#  <td>healthcare</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-512"><a href="#cite_note-512">[512]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="new" href="/w/index.php?title=MyFitnessPal_(Under_Armour_subsidiary&amp;action=edit&amp;redlink=1" title="MyFitnessPal (Under Armour subsidiary (page does not exist)">MyFitnessPal (Under Armour subsidiary</a></td>
#  <td>2018
#  </td>
#  <td>150,000,000</td>
#  <td>consumer goods</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-513"><a href="#cite_note-513">[513]</a></sup><sup class="reference" id="cite_ref-514"><a href="#cite_note-514">[514]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/United_Parcel_Service" title="United Parcel Service">UPS</a></td>
#  <td>2014
#  </td>
#  <td>51 locations</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-515"><a href="#cite_note-515">[515]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Vastaamo" title="Vastaamo">Vastaamo</a></td>
#  <td>2020
#  </td>
#  <td>130,000</td>
#  <td>healthcare</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-516"><a href="#cite_note-516">[516]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Verifications.io" title="Verifications.io">Verifications.io</a> (first leak)
#  </td>
#  <td>2019
#  </td>
#  <td>809,000,000
#  </td>
#  <td>online marketing
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-517"><a href="#cite_note-517">[517]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Verifications.io" title="Verifications.io">Verifications.io</a> (total leaks)
#  </td>
#  <td>2019
#  </td>
#  <td>2,000,000,000
#  </td>
#  <td>online marketing
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-518"><a href="#cite_note-518">[518]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Verizon_Communications" title="Verizon Communications">Verizon Communications</a></td>
#  <td>2016
#  </td>
#  <td>1,500,000</td>
#  <td>telecoms</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-519"><a href="#cite_note-519">[519]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>View Media
#  </td>
#  <td>2020
#  </td>
#  <td>38,000,000
#  </td>
#  <td>online marketing
#  </td>
#  <td>publicly accessible Amazon Web Services (AWS) server
#  </td>
#  <td><sup class="reference" id="cite_ref-520"><a href="#cite_note-520">[520]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Virgin_Media" title="Virgin Media">Virgin Media</a></td>
#  <td>2020
#  </td>
#  <td>900,000</td>
#  <td>mobile carrier</td>
#  <td>accidentally exposed</td>
#  <td><sup class="reference" id="cite_ref-521"><a href="#cite_note-521">[521]</a></sup><sup class="reference" id="cite_ref-522"><a href="#cite_note-522">[522]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Vodafone" title="Vodafone">Vodafone</a></td>
#  <td>2013
#  </td>
#  <td>2,000,000</td>
#  <td>telecoms</td>
#  <td>inside job</td>
#  <td><sup class="reference" id="cite_ref-523"><a href="#cite_note-523">[523]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/VTech" title="VTech">VTech</a></td>
#  <td>2015
#  </td>
#  <td>5,000,000</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-524"><a href="#cite_note-524">[524]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Walmart" title="Walmart">Walmart</a></td>
#  <td>2015
#  </td>
#  <td>1,300,000</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-nytimes.com_225-1"><a href="#cite_note-nytimes.com-225">[225]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Washington_Post" title="Washington Post">Washington Post</a></td>
#  <td>2011
#  </td>
#  <td>1,270,000</td>
#  <td>media</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-525"><a href="#cite_note-525">[525]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Wattpad" title="Wattpad">Wattpad</a></td>
#  <td>2020
#  </td>
#  <td>270,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-526"><a href="#cite_note-526">[526]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Wawa_(company)" title="Wawa (company)">Wawa (company)</a></td>
#  <td>2020
#  </td>
#  <td>30,000,000</td>
#  <td>retail</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-527"><a href="#cite_note-527">[527]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Weebly" title="Weebly">Weebly</a></td>
#  <td>2016
#  </td>
#  <td>43,430,316</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-528"><a href="#cite_note-528">[528]</a></sup><sup class="reference" id="cite_ref-529"><a href="#cite_note-529">[529]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/WellNow_Urgent_Care" title="WellNow Urgent Care">Wellnow Urgent Care</a>
#  </td>
#  <td>2023
#  </td>
#  <td>patients’ names, dates of birth, health information
#  </td>
#  <td>healthcare
#  </td>
#  <td>ransomware hacked
#  </td>
#  <td><sup class="reference" id="cite_ref-530"><a href="#cite_note-530">[530]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Wendy%27s" title="Wendy's">Wendy's</a></td>
#  <td>2015
#  </td>
#  <td>unknown</td>
#  <td>restaurant</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-531"><a href="#cite_note-531">[531]</a></sup><sup class="reference" id="cite_ref-532"><a href="#cite_note-532">[532]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Westpac" title="Westpac">Westpac</a></td>
#  <td>2019
#  </td>
#  <td>98,000</td>
#  <td>financial</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-9Finance_533-0"><a href="#cite_note-9Finance-533">[533]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Woodruff_Arts_Center" title="Woodruff Arts Center">Woodruff Arts Center</a></td>
#  <td>2019
#  </td>
#  <td>unknown</td>
#  <td>arts group</td>
#  <td>poor security</td>
#  <td><sup class="reference" id="cite_ref-534"><a href="#cite_note-534">[534]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/WordPress" title="WordPress">WordPress</a></td>
#  <td>2018
#  </td>
#  <td>thousands of websites</td>
#  <td>web services</td>
#  <td>vulnerabilities in plugins</td>
#  <td><sup class="reference" id="cite_ref-535"><a href="#cite_note-535">[535]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Writerspace.com</td>
#  <td>2011
#  </td>
#  <td>62,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-536"><a href="#cite_note-536">[536]</a></sup>
#  </td></tr>,
#  <tr>
#  <td>Xat.com
#  </td>
#  <td>2015
#  </td>
#  <td>6,054,459
#  </td>
#  <td>web
#  </td>
#  <td>social engineering
#  </td>
#  <td><sup class="reference" id="cite_ref-537"><a href="#cite_note-537">[537]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/2013_Yahoo!_data_breach" title="2013 Yahoo! data breach">Yahoo</a></td>
#  <td>2013
#  </td>
#  <td>3,000,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-538"><a href="#cite_note-538">[538]</a></sup><sup class="reference" id="cite_ref-wsj_oct2017_539-0"><a href="#cite_note-wsj_oct2017-539">[539]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/2014_Yahoo!_data_breach" title="2014 Yahoo! data breach">Yahoo</a></td>
#  <td>2014
#  </td>
#  <td>500,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-540"><a href="#cite_note-540">[540]</a></sup><sup class="reference" id="cite_ref-541"><a href="#cite_note-541">[541]</a></sup><sup class="reference" id="cite_ref-542"><a href="#cite_note-542">[542]</a></sup><sup class="reference" id="cite_ref-543"><a href="#cite_note-543">[543]</a></sup><sup class="reference" id="cite_ref-544"><a href="#cite_note-544">[544]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Yahoo!_data_breach" title="Yahoo! data breach">Yahoo!</a></td>
#  <td>2016
#  </td>
#  <td></td>
#  <td></td>
#  <td>apparent "state-sponsored" data breach</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td><a class="mw-redirect" href="/wiki/Yahoo_Japan" title="Yahoo Japan">Yahoo Japan</a></td>
#  <td>2013
#  </td>
#  <td>22,000,000</td>
#  <td>tech, web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-545"><a href="#cite_note-545">[545]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/2012_Yahoo!_Voices_hack" title="2012 Yahoo! Voices hack">Yahoo! Voices</a></td>
#  <td>2012
#  </td>
#  <td>450,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-546"><a href="#cite_note-546">[546]</a></sup><sup class="reference" id="cite_ref-547"><a href="#cite_note-547">[547]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/YouTube" title="YouTube">YouTube</a>
#  </td>
#  <td>2020
#  </td>
#  <td>4,000,000
#  </td>
#  <td>social media
#  </td>
#  <td>poor security
#  </td>
#  <td><sup class="reference" id="cite_ref-Winder_343-2"><a href="#cite_note-Winder-343">[343]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Zappos" title="Zappos">Zappos</a></td>
#  <td>2012
#  </td>
#  <td>24,000,000</td>
#  <td>web</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-andygreenberg_548-0"><a href="#cite_note-andygreenberg-548">[548]</a></sup>
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Zynga" title="Zynga">Zynga</a></td>
#  <td>2019
#  </td>
#  <td>173,000,000</td>
#  <td>social network</td>
#  <td>hacked</td>
#  <td><sup class="reference" id="cite_ref-549"><a href="#cite_note-549">[549]</a></sup><sup class="reference" id="cite_ref-550"><a href="#cite_note-550">[550]</a></sup>
#  </td></tr>]

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    print(individual_row_data)
    length = len(df)
    df.loc[length] = individual_row_data
# Out:
# ['21st Century Oncology', '2015', "2,200,000 customer's data, including names, Social Security numbers, physicians, diagnoses, insurance information", 'healthcare', 'hacked', '[114][115][116]']
# ['23andMe data leak', '2023', '6,900,000', 'consumer genetics', 'credential stuffing', '[117]']
# ['500px', '2020', '14,870,304', 'social networking', 'hacked', '[118]']
# ['Accendo Insurance Co.', '2020', '175,350', 'healthcare', 'poor security', '[119][120]']
# ['Accenture', '2007', '', '', '', '[citation needed]']
# ['Adobe Systems Incorporated', '2013', '152,000,000', 'tech', 'hacked', '[121][122]']
# ['Adobe Inc.', '2019', '7,500,000', 'tech', 'poor security', '[123][124]']
# ['Advocate Medical Group', '2017', '4,000,000', 'healthcare', 'lost / stolen media', '[125][126]']
# ['AerServ (subsidiary of InMobi)', '2018', '75,000', 'advertising', 'hacked', '[127]']
# ['Affinity Health Plan, Inc.', '2013', '344,579', 'healthcare', 'lost / stolen media', '[128][129]']
# ['Airtel', '2019', '320,000,000', 'telecommunications', 'poor security', '[130]']
# ['Air Canada', '2018', '20,000', 'transport', 'hacked', '[131]']
# ['Amazon Japan G.K.', '2019', 'unknown', 'web', 'accidentally published', '[132][133]']
# ['TD Ameritrade', '2005', '200,000', 'financial', 'lost / stolen media', '[134]']
# ['Ameriprise Financial', '2005', '260,000 customer records', 'financial', 'stolen laptop', '[135]']
# ['Ancestry.com', '2021', '300,000', 'web', 'poor security', '[136]']
# ['Animal Jam', '2020', '46,000,000', 'gaming', 'hacked', '[137][138]']
# ['Ankle & Foot Center of Tampa Bay, Inc.', '2021', '156,000', 'healthcare', 'hacked', '[139]']
# ['Anthem Inc.', '2015', '80,000,000', 'healthcare', 'hacked', '[140][141][142]']
# ['AOL', '2004', '92,000,000', 'web', 'inside job, hacked', '[143][144]']
# ['AOL', '2006', '20,000,000', 'web', 'accidentally published, (sometimes referred to as a "Data Valdez",[145][146][147] due to its size)', '[148]']
# ['AOL', '2014', '2,400,000', 'web', 'hacked', '[149]']
# ['Apple iCloud', '2014', 'photographs of celebrities', 'tech, cloud storage', '', '[150][151]']
# ['Apple, Inc./BlueToad', '2021', '12,367,232', 'tech, retail', 'accidentally published', '[152]']
# ['Apple', '2013', '275,000', 'tech', 'hacked', '[153]']
# ['Apple Health Medicaid', '2021', '91,000', 'healthcare', 'poor security', '[154]']
# ['Ashley Madison', '2015', '32,000,000', 'web', 'hacked', '[155][156]']
# ['AT&T', '2008', '113,000', 'telecoms', 'lost / stolen computer', '[20]']
# ['AT&T', '2010', '114,000', 'telecoms', 'hacked', '[157]']
# ['AT&T', '2021', '72,000,000', 'telecoms', 'unknown', '[158]']
# ['Atraf', '2021', 'unknown', 'dating', 'hacked', '[159]']
# ['Auction.co.kr', '2008', '18,000,000', 'web', 'hacked', '[160]']
# ['Automatic Data Processing', '2005', '125,000', 'financial', 'poor security', '[161]']
# ['AvMed, Inc.', '2009', '1,220,000', 'healthcare', 'lost / stolen computer', '[162]']
# ["Bailey's Inc.", '2015', '250,000', 'retail', 'hacked', '[163]']
# ['The Bank of New York Mellon', '2008', '12,500,000', 'financial', 'lost / stolen media', '[164]']
# ['Bank of America', '2005', '1,200,000', 'financial', 'lost / stolen media', '[165]']
# ['Barnes & Noble', '2012', '63 stores', 'retail', 'hacked', '[166][167]']
# ['Bell Canada', '2017', '1,900,000', 'telecoms', 'poor security', '[168]']
# ['Bell Canada', '2018', '100,000', 'telecoms', 'hacked', '[169]']
# ['Benesse', '2014', '35,040,000', 'educational services', 'hacked', '[170]']
# ['Betfair', '2010', '2,300,000', 'web', 'hacked', '[20]']
# ['Bethesda Game Studios', '2011', '200,000', 'gaming', 'hacked', '[171]']
# ['Bethesda Game Studios', '2018', 'customer names, addresses, contact details, partial credit card numbers', 'gaming', 'accidentally published', '[172]']
# ['Betsson Group', '2020', 'unknown', 'gambling', 'unknown', '[173]']
# ['Blank Media Games', '2018', '7,633,234', 'gaming', 'hacked', '[174][175]']
# ['Blizzard Entertainment', '2012', '14,000,000', 'gaming', 'hacked', '[176][177]']
# ['BlueCross BlueShield of Tennessee', '2009', '1,023,209', 'healthcare', 'lost / stolen media', '[178]']
# ['BMO and Simplii', '2018', '90,000', 'banking', 'poor security', '[179]']
# ['Boeing', '2006', '382,000 employees (after similar losses of data on 3,600 employees in April and 161,000 employees in November, 2005)', 'aviation', '[135]']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 6
#       4 print(individual_row_data)
#       5 length = len(df)
# ----> 6 df.loc[length] = individual_row_data
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1825, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1822     indexer, missing = convert_missing_indexer(indexer)
#    1824     if missing:
# -> 1825         self._setitem_with_indexer_missing(indexer, value)
#    1826         return
#    1828 if name == "loc":
#    1829     # must come after setting of missing
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:2158, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2155     if is_list_like_indexer(value):
#    2156         # must have conforming columns
#    2157         if len(value) != len(self.obj.columns):
# -> 2158             raise ValueError("cannot set a row with mismatched columns")
#    2160     value = Series(value, index=self.obj.columns, name=indexer)
#    2162 if not len(self.obj):
#    2163     # We will ignore the existing dtypes instead of using
#    2164     #  internals.concat logic
#
# ValueError: cannot set a row with mismatched columns

# %%
df
# Out:
#                                        Entity  Year  \
# 0    50 companies and government institutions  2022
# 1                       21st Century Oncology  2015
# 2                           23andMe data leak  2023
# 3                                       500px  2020
# 4                       Accendo Insurance Co.  2020
# ..                                        ...   ...
# 143                             Betsson Group  2020
# 144                         Blank Media Games  2018
# 145                    Blizzard Entertainment  2012
# 146         BlueCross BlueShield of Tennessee  2009
# 147                           BMO and Simplii  2018
#
#                                                Records  Organization type  \
# 0                                            6,400,000            various
# 1    2,200,000 customer's data, including names, So...         healthcare
# 2                                            6,900,000  consumer genetics
# 3                                           14,870,304  social networking
# 4                                              175,350         healthcare
# ..                                                 ...                ...
# 143                                            unknown           gambling
# 144                                          7,633,234             gaming
# 145                                         14,000,000             gaming
# 146                                          1,023,209         healthcare
# 147                                             90,000            banking
#
#                   Method          Sources
# 0          poor security       [112][113]
# 1                 hacked  [114][115][116]
# 2    credential stuffing            [117]
# 3                 hacked            [118]
# 4          poor security       [119][120]
# ..                   ...              ...
# 143              unknown            [173]
# 144               hacked       [174][175]
# 145               hacked       [176][177]
# 146  lost / stolen media            [178]
# 147        poor security            [179]
#
# [148 rows x 6 columns]
